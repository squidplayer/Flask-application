# %%
import numpy as np
import pandas as pd

# %%
car=pd.read_csv('./train-data.csv')

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
car.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %% [markdown]
# ## Quality
#   #Remove New Price Column
#   #keep first word of name
#   #power in object
#   #Transmission is object
#   #Mileage is object
#  # Engin is  object
#  #1  Se is Float

# %% [markdown]
# #Cleanig

# %%
backup=car.copy()

# %%
car=backup
car['Power']=car['Power'].str.split(' ').str.get(0)

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
car['Mileage']
# Out:
# 0       26.6 km/kg
# 1       19.67 kmpl
# 2        18.2 kmpl
# 3       20.77 kmpl
# 4        15.2 kmpl
#            ...
# 6014     28.4 kmpl
# 6015     24.4 kmpl
# 6016     14.0 kmpl
# 6017     18.9 kmpl
# 6018    25.44 kmpl
# Name: Mileage, Length: 6019, dtype: object

# %%
car['Mileage']=car['Mileage']=car['Mileage'].str.split(' ').str.get(0)

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type Mileage   Engine  \
# ...

# %%
car['Engine']=car['Engine']=car['Engine'].str.split(' ').str.get(0)

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type Mileage Engine  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
car=car[~car['Mileage'].isna()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6017 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6017 non-null   int64
#  1   Name               6017 non-null   object
#  2   Location           6017 non-null   object
#  3   Year               6017 non-null   int64
#  4   Kilometers_Driven  6017 non-null   int64
#  5   Fuel_Type          6017 non-null   object
#  6   Transmission       6017 non-null   object
#  7   Owner_Type         6017 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5981 non-null   object
#  10  Power              5981 non-null   object
#  11  Seats              5975 non-null   float64
#  12  New_Price          823 non-null    object
#  13  Price              6017 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 705.1+ KB

# %%
car=car[~car['Engine'].isna()]

# %%
car=car[~car['Power'].isna()]

# %%
car=car[~car['Seats'].isna()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5975 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5975 non-null   int64
#  1   Name               5975 non-null   object
#  2   Location           5975 non-null   object
#  3   Year               5975 non-null   int64
#  4   Kilometers_Driven  5975 non-null   int64
#  5   Fuel_Type          5975 non-null   object
#  6   Transmission       5975 non-null   object
#  7   Owner_Type         5975 non-null   object
#  8   Mileage            5975 non-null   object
#  9   Engine             5975 non-null   object
#  10  Power              5975 non-null   object
#  11  Seats              5975 non-null   float64
#  12  New_Price          823 non-null    object
#  13  Price              5975 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 700.2+ KB

# %%
car['Mileage']=car['Mileage'].astype(float)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5975 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5975 non-null   int64
#  1   Name               5975 non-null   object
#  2   Location           5975 non-null   object
#  3   Year               5975 non-null   int64
#  4   Kilometers_Driven  5975 non-null   int64
#  5   Fuel_Type          5975 non-null   object
#  6   Transmission       5975 non-null   object
#  7   Owner_Type         5975 non-null   object
#  8   Mileage            5975 non-null   float64
#  9   Engine             5975 non-null   object
#  10  Power              5975 non-null   object
#  11  Seats              5975 non-null   float64
#  12  New_Price          823 non-null    object
#  13  Price              5975 non-null   float64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 700.2+ KB

# %%
car['Engine']=car['Engine'].astype(float)

# %%
car['Power'] = pd.to_numeric(car['Power'],errors='coerce')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5975 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5975 non-null   int64
#  1   Name               5975 non-null   object
#  2   Location           5975 non-null   object
#  3   Year               5975 non-null   int64
#  4   Kilometers_Driven  5975 non-null   int64
#  5   Fuel_Type          5975 non-null   object
#  6   Transmission       5975 non-null   object
#  7   Owner_Type         5975 non-null   object
#  8   Mileage            5975 non-null   float64
#  9   Engine             5975 non-null   float64
#  10  Power              5872 non-null   float64
#  11  Seats              5975 non-null   float64
#  12  New_Price          823 non-null    object
#  13  Price              5975 non-null   float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 700.2+ KB

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
car['Name']
# Out:
# 0                 Maruti Wagon R LXI CNG
# 1       Hyundai Creta 1.6 CRDi SX Option
# 2                           Honda Jazz V
# 3                      Maruti Ertiga VDI
# 4        Audi A4 New 2.0 TDI Multitronic
#                       ...
# 6014                    Maruti Swift VDI
# 6015            Hyundai Xcent 1.1 CRDi S
# 6016               Mahindra Xylo D4 BSIV
# 6017                  Maruti Wagon R VXI
# 6018               Chevrolet Beat Diesel
# Name: Name, Length: 5975, dtype: object

# %%
new = car["Name"].str.split(" ", n = 1, expand = True)

# %%
car['Company']=new[0]
car['Model']=new[1]

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
car.drop(columns =["Name"], inplace = True)

# %%
car
# Out:
#       Unnamed: 0    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0              0      Mumbai  2010              72000       CNG       Manual
# 1              1        Pune  2015              41000    Diesel       Manual
# 2              2     Chennai  2011              46000    Petrol       Manual
# 3              3     Chennai  2012              87000    Diesel       Manual
# 4              4  Coimbatore  2013              40670    Diesel    Automatic
# ...          ...         ...   ...                ...       ...          ...
# 6014        6014       Delhi  2014              27365    Diesel       Manual
# 6015        6015      Jaipur  2015             100000    Diesel       Manual
# 6016        6016      Jaipur  2012              55000    Diesel       Manual
# 6017        6017     Kolkata  2013              46000    Petrol       Manual
# 6018        6018   Hyderabad  2011              47000    Diesel       Manual
#
# ...

# %%
car.drop(columns =["Unnamed: 0"], inplace = True)

# %%
 car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5975 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           5975 non-null   object
#  1   Year               5975 non-null   int64
#  2   Kilometers_Driven  5975 non-null   int64
#  3   Fuel_Type          5975 non-null   object
#  4   Transmission       5975 non-null   object
#  5   Owner_Type         5975 non-null   object
#  6   Mileage            5975 non-null   float64
#  7   Engine             5975 non-null   float64
#  8   Power              5872 non-null   float64
#  9   Seats              5975 non-null   float64
#  10  New_Price          823 non-null    object
#  11  Price              5975 non-null   float64
#  12  Company            5975 non-null   object
#  13  Model              5975 non-null   object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 700.2+ KB

# %%
car
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
# ...

# %%
car=car.loc[:,['Company','Model','Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage','Engine','Power','Seats','Price']]

# %%
car
# Out:
#         Company                       Model    Location  Year  \
# 0        Maruti             Wagon R LXI CNG      Mumbai  2010
# 1       Hyundai    Creta 1.6 CRDi SX Option        Pune  2015
# 2         Honda                      Jazz V     Chennai  2011
# 3        Maruti                  Ertiga VDI     Chennai  2012
# 4          Audi  A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...         ...                         ...         ...   ...
# 6014     Maruti                   Swift VDI       Delhi  2014
# 6015    Hyundai            Xcent 1.1 CRDi S      Jaipur  2015
# 6016   Mahindra                Xylo D4 BSIV      Jaipur  2012
# 6017     Maruti                 Wagon R VXI     Kolkata  2013
# 6018  Chevrolet                 Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0                 72000       CNG       Manual      First    26.60   998.0
# ...

# %%
car.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  5975.000000       5.975000e+03  5975.000000  5975.000000  5872.000000
# mean   2013.386778       5.867431e+04    18.179408  1621.606695   113.276894
# std       3.247238       9.155851e+04     4.521801   601.036987    53.881892
# min    1998.000000       1.710000e+02     0.000000   624.000000    34.200000
# 25%    2012.000000       3.390800e+04    15.200000  1198.000000    75.000000
# 50%    2014.000000       5.300000e+04    18.160000  1493.000000    97.700000
# 75%    2016.000000       7.300000e+04    21.100000  1984.000000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  5975.000000  5975.000000
# mean      5.278828     9.501647
# std       0.808959    11.205736
# min       0.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.650000
# 75%       5.000000     9.950000
# ...

# %%
car=car[car['Price']<15].reset_index(drop=True)

# %%
car.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  4981.000000        4981.000000  4981.000000  4981.000000  4881.000000
# mean   2013.090745       59613.926119    18.827950  1462.949207    96.595052
# std       3.327655       39424.717748     4.367452   460.250489    34.761619
# min    1998.000000         171.000000     0.000000   624.000000    34.200000
# 25%    2011.000000       35059.000000    16.100000  1197.000000    74.000000
# 50%    2014.000000       55000.000000    18.900000  1373.000000    88.500000
# 75%    2016.000000       75000.000000    21.900000  1586.000000   112.000000
# max    2019.000000      775000.000000    33.540000  4806.000000   500.000000
#
#              Seats        Price
# count  4981.000000  4981.000000
# mean      5.258382     5.481911
# std       0.756559     3.066179
# min       2.000000     0.440000
# 25%       5.000000     3.200000
# 50%       5.000000     4.850000
# 75%       5.000000     7.000000
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            4981 non-null   object
#  1   Model              4981 non-null   object
#  2   Location           4981 non-null   object
#  3   Year               4981 non-null   int64
#  4   Kilometers_Driven  4981 non-null   int64
#  5   Fuel_Type          4981 non-null   object
#  6   Transmission       4981 non-null   object
#  7   Owner_Type         4981 non-null   object
#  8   Mileage            4981 non-null   float64
#  9   Engine             4981 non-null   float64
#  10  Power              4881 non-null   float64
#  11  Seats              4981 non-null   float64
#  12  Price              4981 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 506.0+ KB

# %%
car=car[~car['Power'].isna()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4881 entries, 0 to 4980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            4881 non-null   object
#  1   Model              4881 non-null   object
#  2   Location           4881 non-null   object
#  3   Year               4881 non-null   int64
#  4   Kilometers_Driven  4881 non-null   int64
#  5   Fuel_Type          4881 non-null   object
#  6   Transmission       4881 non-null   object
#  7   Owner_Type         4881 non-null   object
#  8   Mileage            4881 non-null   float64
#  9   Engine             4881 non-null   float64
#  10  Power              4881 non-null   float64
#  11  Seats              4881 non-null   float64
#  12  Price              4881 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 533.9+ KB

# %%
car.to_csv('cleaned_car.csv')

# %% [markdown]
# ## Model

# %%
x=car.drop(columns='Price')
y=car['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
car.info()
x_test
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4881 entries, 0 to 4980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            4881 non-null   object
#  1   Model              4881 non-null   object
#  2   Location           4881 non-null   object
#  3   Year               4881 non-null   int64
#  4   Kilometers_Driven  4881 non-null   int64
#  5   Fuel_Type          4881 non-null   object
#  6   Transmission       4881 non-null   object
#  7   Owner_Type         4881 non-null   object
#  8   Mileage            4881 non-null   float64
#  9   Engine             4881 non-null   float64
#  10  Power              4881 non-null   float64
#  11  Seats              4881 non-null   float64
#  12  Price              4881 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 533.9+ KB
#       Company                        Model    Location  Year  \
# ...

# %%
ohe=OneHotEncoder()
ohe.fit(x[['Company','Model','Location','Fuel_Type','Transmission','Owner_Type']])
# Out:
# OneHotEncoder()

# %%
x[['Company','Model','Location','Fuel_Type','Transmission','Owner_Type']]
# Out:
#         Company                     Model   Location Fuel_Type Transmission  \
# 0        Maruti           Wagon R LXI CNG     Mumbai       CNG       Manual
# 1       Hyundai  Creta 1.6 CRDi SX Option       Pune    Diesel       Manual
# 2         Honda                    Jazz V    Chennai    Petrol       Manual
# 3        Maruti                Ertiga VDI    Chennai    Diesel       Manual
# 4       Hyundai   EON LPG Era Plus Option  Hyderabad       LPG       Manual
# ...         ...                       ...        ...       ...          ...
# 4976     Maruti                 Swift VDI      Delhi    Diesel       Manual
# 4977    Hyundai          Xcent 1.1 CRDi S     Jaipur    Diesel       Manual
# 4978   Mahindra              Xylo D4 BSIV     Jaipur    Diesel       Manual
# 4979     Maruti               Wagon R VXI    Kolkata    Petrol       Manual
# 4980  Chevrolet               Beat Diesel  Hyderabad    Diesel       Manual
#
#      Owner_Type
# 0         First
# 1         First
# ...

# %%
ohe.categories_
# Out:
# [array(['Ambassador', 'Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat',
#         'Force', 'Ford', 'Honda', 'Hyundai', 'ISUZU', 'Land', 'Mahindra',
#         'Maruti', 'Mercedes-Benz', 'Mitsubishi', 'Nissan', 'Porsche',
#         'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#        dtype=object),
#  array(['3 Series 2005-2011 325i Sedan', '3 Series 320d',
#         '3 Series 320d Corporate Edition', ..., 'redi-GO S', 'redi-GO T',
#         'redi-GO T Option'], dtype=object),
#  array(['Ahmedabad', 'Bangalore', 'Chennai', 'Coimbatore', 'Delhi',
#         'Hyderabad', 'Jaipur', 'Kochi', 'Kolkata', 'Mumbai', 'Pune'],
#        dtype=object),
#  array(['CNG', 'Diesel', 'LPG', 'Petrol'], dtype=object),
#  array(['Automatic', 'Manual'], dtype=object),
#  array(['First', 'Fourth & Above', 'Second', 'Third'], dtype=object)]

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Company','Model','Location','Fuel_Type','Transmission','Owner_Type']),remainder='passthrough')

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['Ambassador', 'Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat',
#        'Force', 'Ford', 'Honda', 'Hyundai', 'ISUZU', 'Land', 'Mahindra',
#        'Maruti', 'Mercedes-Benz', 'Mitsubishi', 'Nissan', 'Porsche',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                            arra...
#                                                            array(['Ahmedabad', 'Bangalore', 'Chennai', 'Coimbatore', 'Delhi',
#        'Hyderabad', 'Jaipur', 'Kochi', 'Kolkata', 'Mumbai', 'Pune'],
#       dtype=object),
#                                                            array(['CNG', 'Diesel', 'LPG', 'Petrol'], dtype=object),
#                                                            array(['Automatic', 'Manual'], dtype=object),
# ...

# %%
OneHotEncoder()
# Out:
# OneHotEncoder()

# %%
lr=LinearRegression()

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class InverseTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, column_name):
        self.column_name = column_name

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X[self.column_name] = 1 / X[self.column_name]
        return X

# %%
pipe=make_pipeline( InverseTransformer(column_name="Kilometers_Driven"),column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('inversetransformer',
#                  InverseTransformer(column_name='Kilometers_Driven')),
#                 ('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Ambassador', 'Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat',
#        'Force', 'Ford', 'Honda', 'Hyundai', 'ISUZU', 'Land', 'Mahindra',
#        'Maruti', 'Mercedes-...
#                                                                             array(['Ahmedabad', 'Bangalore', 'Chennai', 'Coimbatore', 'Delhi',
#        'Hyderabad', 'Jaipur', 'Kochi', 'Kolkata', 'Mumbai', 'Pune'],
#       dtype=object),
#                                                                             array(['CNG', 'Diesel', 'LPG', 'Petrol'], dtype=object),
# ...

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8663256750536241

# %%
y_pred
# Out:
# array([ 9.45170918,  7.99128804,  1.39377182,  6.38566504,  9.88567051,
#         5.23266847,  6.57658834, 13.30265847,  6.19904717,  8.07744648,
#         5.87500366,  5.8719278 , -0.02233943,  3.34195485,  7.00466567,
#         8.27839098,  6.29875979,  5.24490367,  7.34567886,  2.83858427,
#         2.29898082,  5.63216278,  4.24666685,  5.15540024,  5.31253643,
#         4.79692081,  7.34431704,  8.68676284,  8.94222951,  0.8198407 ,
#         7.83341893,  5.91522942,  5.24650187,  9.35507849,  2.61990948,
#        -0.07115023,  4.06441213,  6.40283778,  3.76389048,  4.44901028,
#         4.92252433,  3.58404903,  7.42258726,  6.65360452,  2.59856238,
#         4.7587306 ,  3.21507156,  4.68920621,  4.23210777,  5.23202998,
#         4.65344109,  3.81774632,  4.24356466,  5.87226066,  5.41585976,
#         8.26073404, 11.00276554,  4.46794579,  9.61170367,  5.43674177,
#         1.11151591,  5.22803612,  8.58103158,  8.48567618,  5.33660477,
# ...

# %%
scores=[]
for i in range(1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline( InverseTransformer(column_name="Kilometers_Driven"),column_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 143

# %%
scores[np.argmax(scores)]
# Out:
# 0.9103039974587098
